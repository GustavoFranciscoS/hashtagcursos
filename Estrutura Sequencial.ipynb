# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = int(input('Informe um numero de 0 a 10'))
print(numero)
type(numero)
# Out:
# 10
# int

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 = int(input('Qual o primeiro numero?'))
numero2 = int(input('Qual o segundo numero?'))

print(numero1)
print(numero2)

soma = numero1 + numero2

print(f'A soma é {soma}')
# Out:
# 10
# 20
# A soma é 30

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = float(input('Qual a primeira nota?'))
nota2 = float(input('Qual a segunda nota?'))
nota3 = float(input('Qual a terceira nota?'))
nota4 = float(input('Qual a quarta nota?'))

print(f'A primeira nota foi {nota1}')
print(f'A segunda nota foi {nota2}')
print(f'A terceira nota foi {nota3}')
print(f'A quarta nota foi {nota4}')

media = (nota1 + nota2 + nota3 + nota4) / 4

print(f'A média do bimestre foi: {media}')
# Out:
# A primeira nota foi 7.5
# A segunda nota foi 8.6
# A terceira nota foi 6.0
# A quarta nota foi 5.2
# A média do bimestre foi: 6.825

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = int(input('Informe a quantidade em metros:'))

print(metros)

centimetros = metros * 100

print(f'Aquantidade de {metros} metros, em centimetros é: {centimetros} centimetros')
# Out:
# 3
# Aquantidade de 3 metros, em centimetros é: 300 centimetros

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input('Qual a largura da sala?'))
print(f'A largura da sala é {largura}')

comprimento = float(input('Qual o comprimento da sala?'))
print(f'O comprimento da sala é {comprimento}')

metros_quadrados = largura * comprimento
print(f'A sala possui {metros_quadrados} metros quadrados')
# Out:
# A largura da sala é 6.0
# O comprimento da sala é 7.0
# A sala possui 42.0 metros quadrados

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor_hora = float(input('Qual valor você ganha por hora trabalhada?'))
print(valor_hora)

horas_trabalhadas = float(input('Quantas horas você trabalha por mês?'))
print(horas_trabalhadas)

Salario_mensal = valor_hora * horas_trabalhadas
print(f'Seu salário é {Salario_mensal} reais')
# Out:
# 120.0
# 220.0
# Seu salário é 26400.0 reais

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
temperatura_f = float(input('Informe a temperatura em Fahrenehit: '))
temperatura_c = (5/9) * (temperatura_f - 32)
print('A temperatura é:', temperatura_c, '°C')
# Out:
# A temperatura é: 37.77777777777778 °C

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
temperatura_c = float(input('Informe a temperatura em Celcius: '))
temperatura_f = (5/9) * (temperatura_c + 32)
print('A temperatura é:', temperatura_f, '°F')
# Out:
# A temperatura é: 38.05555555555556 °F

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Informe sua altura: '))
peso_ideal = 72.7 * altura - 58
print(F'O seu peso ideal é: {peso_ideal} KG')
# Out:
# O seu peso ideal é: 74.31400000000002 KG

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura_homem = float(input('Informe sua altura: '))
peso_idealHomens = 72.7 * altura - 58
print(F'O seu peso ideal para Homem é: {peso_idealHomens} KG')

altura_mulher = float(input('Informe sua altura: '))
peso_idealMulher = 62.1 * altura - 44.7
print(F'O seu peso ideal para Mulher é: {peso_idealMulher} KG')
# Out:
# O seu peso ideal para Homem é: 74.31400000000002 KG
# O seu peso ideal para Mulher é: 68.322 KG

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
valor_hora = float(input('Qual o valor da sua hora trabalhada?'))
horas_trabalhadas = float(input('Quantas horas você trabalha por mês?'))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = valor_hora * horas_trabalhadas
print(f'O salário bruto é {salario_bruto} reais')
# Out:
# O salário bruto é 26400.0 reais

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
valor_ir = salario_bruto * 0.11
print(f'O valor do IR é {valor_ir}')
# Out:
# O valor do IR é 2904.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
valor_inss = salario_bruto * 0.08
print(f'O valor do INSS é {valor_inss}')
# Out:
# O valor do INSS é 2112.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
valor_sindicato = salario_bruto * 0.05
print(f'O desconto de sindicato é de {valor_sindicato}')
# Out:
# O desconto de sindicato é de 1320.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
descontos_salario = valor_ir + valor_inss + valor_sindicato
salario_liquido = salario_bruto - descontos_salario
print(f'O valor do salário liquido é de {salario_liquido} reais')
# Out:
# O valor do salário liquido é de 20064.0 reais

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = float(input('Informe o tamanho da área a ser pintada em m²'))

litros_tinta = area / 3

latas = litros_tinta / 18
preco = latas * 80

print(f'Serão necessárias {latas} latas, custando R$ {preco} no total')
# Out:
# Serão necessárias 1.0 latas, custando R$ 80.0 no total

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input('Informe o tamanho do arquivo em MB: '))
velocidade = float(input('Informe a velocidade da conexão em Mbps: '))

# aqui trasnformamos megabytes em megabits para que tamanho e velocidade estejam na mesma unidade
tamanho_megabits = tamanho * 8

tempo = tamanho_megabits / velocidade
# transformando em minutos
tempo_minutos = tempo / 60
print(f'O tempo de download é de {tempo_minutos} minutos')
# Out:
# O tempo de download é de 0.3333333333333333 minutos
